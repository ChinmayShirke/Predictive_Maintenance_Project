# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Downloads\modified_data_strong_corr.csv")
data.head()
# Out:
#   machine_id  run_id  cycle  status status1  temperature  vibration  \
# 0  Machine_1       1      1       0    work    64.297273   0.652221
# 1  Machine_1       1      2       0    work    63.549179   0.375174
# 2  Machine_1       1      3       0    work    70.597547   0.462434
# 3  Machine_1       1      4       0    work    74.768373   0.446088
# 4  Machine_1       1      5       0    work    69.496305   0.674186
#
#     pressure   current  rul
# 0  26.143767  4.656356   99
# 1  23.830708  3.407930   98
# 2  22.121501  2.598463   97
# 3  22.100309  4.797719   96
# 4  23.665072  3.525749   95

# %%
data.head()
# Out:
#   machine_id  run_id  cycle  status status1  temperature  vibration  \
# 0  Machine_1       1      1       0    work    64.297273   0.652221
# 1  Machine_1       1      2       0    work    63.549179   0.375174
# 2  Machine_1       1      3       0    work    70.597547   0.462434
# 3  Machine_1       1      4       0    work    74.768373   0.446088
# 4  Machine_1       1      5       0    work    69.496305   0.674186
#
#     pressure   current  rul
# 0  26.143767  4.656356   99
# 1  23.830708  3.407930   98
# 2  22.121501  2.598463   97
# 3  22.100309  4.797719   96
# 4  23.665072  3.525749   95

# %%
data.drop(columns=["status1","machine_id"],inplace=True)

# %%
sns.scatterplot(data=data,x="temperature", y="rul",hue="status")
# Out:
# <Axes: xlabel='temperature', ylabel='rul'>

# %%
sns.scatterplot(data=data,x="pressure", y="rul",hue="status")
# Out:
# <Axes: xlabel='pressure', ylabel='rul'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(
    data=data,
    vars=["rul", "pressure", "temperature", "vibration", "current"],
    hue="status",
   
    diag_kind="kde"
)
plt.suptitle("Advanced Pairwise Correlation Visualization", y=1.02)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
independent=["run_id"	,"cycle",	"status",	'temperature',	"vibration"	,"pressure"	,"current"]
dependent=['rul']

# %%
x=data[independent]
y=data[dependent]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
# Creating a regression model to predict the aggregate rating of a restaurant based on available features
# Import necessary libraries for data splitting, regression, and evaluation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import svm

# %%
# Define a dictionary of regression models to experiment with
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    'Ada Boost':AdaBoostRegressor(n_estimators=50,learning_rate=1),
    'xgboost ':XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=500, objective='reg:linear', booster='gbtree'),
    'KNN':KNeighborsRegressor(),
    'SVM': svm.SVR(C=2, kernel='linear')
}

# Iterate through each model, train, evaluate, and print results
for model_name, model in models.items():
    # Train the model on the training data
    model.fit(X_train, Y_train)

    # Make predictions on the test data
    Y_pred = model.predict(X_test)
    
    # Calculate Mean Squared Error (MSE) to evaluate model accuracy
    mse = mean_squared_error(Y_test, Y_pred)
    
     # Calculate R-squared (R2) to assess the goodness of fit
    r2 = r2_score(Y_test, Y_pred)

    #Accuracy
    a=model.score(X_train,Y_train)*100

    # Print model performance metrics
    print(f"Model: {model_name}")
    print(f"Accuracy:{a}")
    print(f"Mean Squared Error: {mse}")
    print(f"R-squared: {r2}")
    print("-"*20)
# Out:
# Model: Linear Regression
# Accuracy:100.0
# Mean Squared Error: 6.262924498730657e-29
# R-squared: 1.0
# --------------------
# Model: Decision Tree
# Accuracy:100.0
# Mean Squared Error: 0.0
# R-squared: 1.0
# --------------------
# D:\anaconda\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Model: Random Forest
# Accuracy:100.0
# Mean Squared Error: 0.0
# R-squared: 1.0
# --------------------
# Model: Ada Boost
# Accuracy:98.45063996577122
# Mean Squared Error: 13.17857542352377
# R-squared: 0.983831805353698
# --------------------
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
LR =LinearRegression()
DT=DecisionTreeRegressor()
RandomForest=RandomForestRegressor()

LR.fit(X_train, Y_train)
DT.fit(X_train, Y_train)
RandomForest.fit(X_train, Y_train)


LR_pred = LR.predict(X_test)
DT_pred =DT.predict(X_test)
RF_pred = RandomForest.predict(X_test)

TestingDataResults=pd.DataFrame(data=X_test)
TestingDataResults['RUL']=Y_test
TestingDataResults["LR"]=LR_pred
TestingDataResults["DT"]=DT_pred
TestingDataResults["RandomForest"]=RF_pred
TestingDataResults.head(10)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
#       run_id  cycle  status  temperature  vibration   pressure   current  RUL  \
# 9394      94     95       0    86.222822   1.979022  29.125136  6.995104    5
# 898        9     99       0    98.552083   2.297916  30.710477  7.552565    1
# 2398      24     99       0   100.022007   1.622256  29.348930  8.390755    1
# 5906      60      7       0    65.620322   0.492967  25.333286  2.658503   93
# 2343      24     44       0    71.433069   0.891858  27.914399  3.512947   56
# 8225      83     26       0    63.665152   0.577956  28.174668  4.287301   74
# 5506      56      7       0    75.230315   0.787578  25.967631  4.222663   93
# 6451      65     52       0    78.376305   1.334052  27.776883  5.608877   48
# ...

# %%
import pickle

with open("RandomForest.pkl", "wb") as file:
    pickle.dump(RandomForest, file)

# %%
# Create a download link (for Jupyter)
# -------------------------
from IPython.display import FileLink

FileLink("RandomForest.pkl")
# Out:
# C:\Users\AM\RandomForest.pkl
